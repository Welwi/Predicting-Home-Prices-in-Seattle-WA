# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import PolynomialFeatures, RobustScaler
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline, make_pipeline

from sklearn.ensemble import BaggingRegressor
from sklearn.model_selection import cross_validate, cross_val_predict
from pyearth import Earth
from pygam import LinearGAM, GAM, f, s, te

# %%
#This code prevents outputs from having the scroll down


# %%javascript
IPython.OutputArea.prototype._should_scroll = function(lines) {
    return false;
}

# %%
#importing the data and putting it into a pandas dataframe

df = pd.read_csv('../data/kc_house_data_clean.csv', index_col=0)
df.head(2)
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520  10/13/2014  221900.0         3       1.00         1180      5650
# 6414100192   12/9/2014  538000.0         3       2.25         2570      7242
#
#             floors  waterfront  view  condition  ...  zipcode      lat  \
# id                                               ...
# 7129300520     1.0         1.0   0.0          3  ...    98178  47.5112
# 6414100192     2.0         0.0   0.0          3  ...    98125  47.7210
#
#                long  sqft_living15  sqft_lot15  waterfront_null  \
# id
# 7129300520 -122.257           1340        5650                1
# 6414100192 -122.319           1690        7639                0
#
#             waterfront_ind  yr_renovated_scheme1  yr_renovated_null  \
# id
# 7129300520               0                     0                  0
# 6414100192               0                     2                  0
#
#             yr_renovated_ind
# id
# 7129300520                 0
# 6414100192                 1
#
# [2 rows x 24 columns]

# %%
# This shows that the dataset has 20 columns and 21597 columns. 
# Shows the different data types and that 
# There are some missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21597 entries, 7129300520 to 1523300157
# Data columns (total 20 columns):
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(10), object(2)
# memory usage: 3.5+ MB

# %%
# This function shows the first 3 rows and last 3 rows in the dataframe
def peek(df):
    return df.head(3).append(df.tail(3))

# %%
peek(df)
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520  10/13/2014  221900.0         3       1.00         1180      5650
# 6414100192   12/9/2014  538000.0         3       2.25         2570      7242
# 5631500400   2/25/2015  180000.0         2       1.00          770     10000
# 1523300141   6/23/2014  402101.0         2       0.75         1020      1350
# 291310100    1/16/2015  400000.0         3       2.50         1600      2388
# 1523300157  10/15/2014  325000.0         2       0.75         1020      1076
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520     1.0         NaN   0.0          3      7        1180
# 6414100192     2.0         0.0   0.0          3      7        2170
# 5631500400     1.0         0.0   0.0          3      6         770
# 1523300141     2.0         0.0   0.0          3      7        1020
# 291310100      2.0         NaN   0.0          3      8        1600
# 1523300157     2.0         0.0   0.0          3      7        1020
#
#            sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 7129300520           0.0      1955           0.0    98178  47.5112 -122.257
# 6414100192         400.0      1951        1991.0    98125  47.7210 -122.319
# 5631500400           0.0      1933           NaN    98028  47.7379 -122.233
# 1523300141           0.0      2009           0.0    98144  47.5944 -122.299
# 291310100            0.0      2004           0.0    98027  47.5345 -122.069
# 1523300157           0.0      2008           0.0    98144  47.5941 -122.299
#
#             sqft_living15  sqft_lot15
# id
# 7129300520           1340        5650
# 6414100192           1690        7639
# 5631500400           2720        8062
# 1523300141           1020        2007
# 291310100            1410        1287
# 1523300157           1020        1357

# %%
# statistics. A few things can be noted.
# The maximum number of bedrooms in the dataset is 33. 
# Some houses have less than 1 bathroom
df.describe().T
# Out:
#                  count           mean            std         min          25%  \
# price          21597.0  540296.573506  367368.140101  78000.0000  322000.0000
# bedrooms       21597.0       3.373200       0.926299      1.0000       3.0000
# bathrooms      21597.0       2.115826       0.768984      0.5000       1.7500
# sqft_living    21597.0    2080.321850     918.106125    370.0000    1430.0000
# sqft_lot       21597.0   15099.408760   41412.636876    520.0000    5040.0000
# floors         21597.0       1.494096       0.539683      1.0000       1.0000
# waterfront     19221.0       0.007596       0.086825      0.0000       0.0000
# view           21534.0       0.233863       0.765686      0.0000       0.0000
# condition      21597.0       3.409825       0.650546      1.0000       3.0000
# grade          21597.0       7.657915       1.173200      3.0000       7.0000
# sqft_above     21597.0    1788.596842     827.759761    370.0000    1190.0000
# yr_built       21597.0    1970.999676      29.375234   1900.0000    1951.0000
# yr_renovated   17755.0      83.636778     399.946414      0.0000       0.0000
# zipcode        21597.0   98077.951845      53.513072  98001.0000   98033.0000
# lat            21597.0      47.560093       0.138552     47.1559      47.4711
# long           21597.0    -122.213982       0.140724   -122.5190    -122.3280
# sqft_living15  21597.0    1986.620318     685.230472    399.0000    1490.0000
# sqft_lot15     21597.0   12758.283512   27274.441950    651.0000    5100.0000
#
#                        50%         75%           max
# price          450000.0000  645000.000  7.700000e+06
# bedrooms            3.0000       4.000  3.300000e+01
# bathrooms           2.2500       2.500  8.000000e+00
# sqft_living      1910.0000    2550.000  1.354000e+04
# sqft_lot         7618.0000   10685.000  1.651359e+06
# floors              1.5000       2.000  3.500000e+00
# waterfront          0.0000       0.000  1.000000e+00
# view                0.0000       0.000  4.000000e+00
# condition           3.0000       4.000  5.000000e+00
# grade               7.0000       8.000  1.300000e+01
# sqft_above       1560.0000    2210.000  9.410000e+03
# yr_built         1975.0000    1997.000  2.015000e+03
# yr_renovated        0.0000       0.000  2.015000e+03
# zipcode         98065.0000   98118.000  9.819900e+04
# lat                47.5718      47.678  4.777760e+01
# long             -122.2310    -122.125 -1.213150e+02
# sqft_living15    1840.0000    2360.000  6.210000e+03
# sqft_lot15       7620.0000   10083.000  8.712000e+05

# %%
# Checking for null values.
# Waterfront, view and yr_renovated have missing values
df.isnull().sum()
# Out:
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
df_water = df[df['waterfront'].isna() == True]
df_water[df_water['yr_renovated'].isna() == True]
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 8091400200   5/16/2014   252700.0         2       1.50         1070      9643
# 5547700270   7/15/2014   625000.0         4       2.50         2570      5520
# 1328310370    4/2/2015   375000.0         3       2.50         2340     10005
# 3127200041   6/13/2014   589000.0         4       3.00         2440      9600
# 2264500350   4/18/2015   615000.0         4       1.00         1330      2400
# ...                ...        ...       ...        ...          ...       ...
# 2937300430   9/29/2014   928990.0         4       2.50         3570      6054
# 3448740360   4/29/2015   418500.0         4       2.50         2190      4866
# 6891100090  10/14/2014   850000.0         5       3.50         4200      5400
# 4233600150    2/3/2015  1150000.0         5       4.25         4010      8252
# 9521100867   7/11/2014   475000.0         3       3.25         1380      1121
#
#             floors  waterfront  view  condition  grade  sqft_above  \
# id
# 8091400200     1.0         NaN   0.0          3      7        1070
# 5547700270     2.0         NaN   0.0          3      9        2570
# 1328310370     1.0         NaN   0.0          4      8        1460
# 3127200041     2.0         NaN   0.0          5      7        2440
# 2264500350     1.5         NaN   0.0          4      6        1330
# ...            ...         ...   ...        ...    ...         ...
# 2937300430     2.0         NaN   0.0          3      9        3570
# 3448740360     2.0         NaN   0.0          3      7        2190
# 6891100090     2.0         NaN   0.0          3      9        3140
# 4233600150     2.0         NaN   0.0          3     10        4010
# 9521100867     3.0         NaN   0.0          3      8        1380
#
#            sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 8091400200           0.0      1985           NaN    98030  47.3533 -122.166
# 5547700270           0.0      2000           NaN    98074  47.6145 -122.027
# 1328310370         880.0      1978           NaN    98058  47.4431 -122.133
# 3127200041           0.0      1961           NaN    98034  47.7044 -122.200
# 2264500350           0.0      1901           NaN    98103  47.6500 -122.340
# ...                  ...       ...           ...      ...      ...      ...
# 2937300430           0.0      2014           NaN    98052  47.7053 -122.126
# 3448740360           0.0      2009           NaN    98059  47.4907 -122.152
# 6891100090        1060.0      2012           NaN    98052  47.7077 -122.120
# 4233600150           0.0      2015           NaN    98075  47.5974 -122.013
# 9521100867           0.0      2008           NaN    98103  47.6617 -122.349
#
#             sqft_living15  sqft_lot15
# id
# 8091400200           1220        8386
# 5547700270           2470        5669
# 1328310370           2250        8162
# 3127200041           2290        9600
# 2264500350           1330        4400
# ...                   ...         ...
# 2937300430           3600        6050
# 3448740360           2190        5670
# 6891100090           3300        5564
# 4233600150           3370        8252
# 9521100867           1310        1405
#
# [430 rows x 20 columns]

# %%
# 19075 of the houses are not in the waterfront. 146 are on the waterfront. 
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0      146
# Name: waterfront, dtype: int64

# %% [markdown]
# ### Handling missing values for waterfront and yr_renovated

# %% [markdown]
# Since the model can not handle missing values and waterfront seemed to be an important feature, we did the following steps to handle the missing values in the waterfront.
#     - Houses not in the waterfront will have a value 0
#     - Houses where waterfront has null values will will have a value of 1.
#     - Houses in the waterfront will have a value of 2
#
# We then created 2 columns with binary indicators:
#     - 'waterfront_null' : in which 0 are the ones we know that have/don't have waterfront, while 1 are the ones we do not know (NaN values)
#     - 'waterfront_ind': in which 1 represents the houses that we know that have a waterfront.
#
#
# A column called 'yr_renovated_schema1' was created in which:
#     - 0 represents houses that have never been renovated
#     - 1 represents houses with missing values, so we don't know if they have been renovated
#     - 2 represents the houses that the data shows that they have been renovated.
#
# The columns with the binary indicators show:
#     - 'yr_renovated_null': 1 shows all the houses that we do not know if they have been renovated and 0 represents all the other houses.
#     - 'yr_renovated_ind': 1 shows houses that we know that have been renovated, while 0 represents all the other houses.

# %%
idx = df['waterfront'] == 1
df['waterfront'].loc[idx] = 2

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 2.0      146
# Name: waterfront, dtype: int64

# %%
idx = df['waterfront'].isna() == True
df['waterfront'].loc[idx] = 1

# %%
df['waterfront'].value_counts()
# Out:
# 0.0    19075
# 1.0     2376
# 2.0      146
# Name: waterfront, dtype: int64

# %%
df['waterfront_null'] = df['waterfront'].apply(lambda x: 1 if x == 1 else 0)
df['waterfront_null'].value_counts()
# Out:
# 0    19221
# 1     2376
# Name: waterfront_null, dtype: int64

# %%
df['waterfront_ind'] = df['waterfront'].apply(lambda x: 1 if x == 2 else 0)
df['waterfront_ind'].value_counts()
# Out:
# 0    21451
# 1      146
# Name: waterfront_ind, dtype: int64

# %%
df['yr_renovated'].value_counts()
# Out:
# 0.0       17011
# 2014.0       73
# 2003.0       31
# 2013.0       31
# 2007.0       30
#           ...
# 1946.0        1
# 1959.0        1
# 1971.0        1
# 1951.0        1
# 1954.0        1
# Name: yr_renovated, Length: 70, dtype: int64

# %%
df['yr_renovated_scheme1'] = 0

idx = df['yr_renovated'] > 0
df['yr_renovated_scheme1'].loc[idx] = 2

idx = df['yr_renovated'].isna() == True
df['yr_renovated_scheme1'].loc[idx] = 1

df['yr_renovated_scheme1'].value_counts()
# Out:
# 0    17011
# 1     3842
# 2      744
# Name: yr_renovated_scheme1, dtype: int64

# %%
df['yr_renovated_null'] = df['yr_renovated_scheme1'].apply(lambda x: 1 if x == 1 else 0)
df['yr_renovated_null'].value_counts()
# Out:
# 0    17755
# 1     3842
# Name: yr_renovated_null, dtype: int64

# %%
df['yr_renovated_ind'] = df['yr_renovated_scheme1'].apply(lambda x: 1 if x == 2 else 0)
df['yr_renovated_ind'].value_counts()
# Out:
# 0    20853
# 1      744
# Name: yr_renovated_ind, dtype: int64

# %%
# Shows the correlation of each feature with the target variable.
df.corr()['price'].abs().sort_values(ascending=False)
# Out:
# price                   1.000000
# sqft_living             0.701917
# grade                   0.667951
# sqft_above              0.605368
# sqft_living15           0.585241
# bathrooms               0.525906
# view                    0.395734
# bedrooms                0.308787
# lat                     0.306692
# waterfront_ind          0.264306
# floors                  0.256804
# yr_renovated            0.129599
# yr_renovated_ind        0.117543
# waterfront              0.114792
# sqft_lot                0.089876
# yr_renovated_scheme1    0.083330
# sqft_lot15              0.082845
# yr_built                0.053953
# zipcode                 0.053402
# condition               0.036056
# long                    0.022036
# waterfront_null         0.010400
# yr_renovated_null       0.002127
# Name: price, dtype: float64

# %%
df.shape
# Out:
# (21597, 25)

# %%
sns.scatterplot(df['long'],df['lat'])

# %%
# Some of the datapoints are farther away from the main area of interest, so they are going to be removed.
df[df['long'] < -121.85]
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520  10/13/2014  221900.0         3       1.00         1180      5650
# 6414100192   12/9/2014  538000.0         3       2.25         2570      7242
# 5631500400   2/25/2015  180000.0         2       1.00          770     10000
# 2487200875   12/9/2014  604000.0         4       3.00         1960      5000
# 1954400510   2/18/2015  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 263000018    5/21/2014  360000.0         3       2.50         1530      1131
# 6600060120   2/23/2015  400000.0         4       2.50         2310      5813
# 1523300141   6/23/2014  402101.0         2       0.75         1020      1350
# 291310100    1/16/2015  400000.0         3       2.50         1600      2388
# 1523300157  10/15/2014  325000.0         2       0.75         1020      1076
#
#             floors  waterfront  view  condition  ...  zipcode      lat  \
# id                                               ...
# 7129300520     1.0         1.0   0.0          3  ...    98178  47.5112
# 6414100192     2.0         0.0   0.0          3  ...    98125  47.7210
# 5631500400     1.0         0.0   0.0          3  ...    98028  47.7379
# 2487200875     1.0         0.0   0.0          5  ...    98136  47.5208
# 1954400510     1.0         0.0   0.0          3  ...    98074  47.6168
# ...            ...         ...   ...        ...  ...      ...      ...
# 263000018      3.0         0.0   0.0          3  ...    98103  47.6993
# 6600060120     2.0         0.0   0.0          3  ...    98146  47.5107
# 1523300141     2.0         0.0   0.0          3  ...    98144  47.5944
# 291310100      2.0         1.0   0.0          3  ...    98027  47.5345
# 1523300157     2.0         0.0   0.0          3  ...    98144  47.5941
#
#                long  sqft_living15  sqft_lot15  waterfront_null  \
# id
# 7129300520 -122.257           1340        5650                1
# 6414100192 -122.319           1690        7639                0
# 5631500400 -122.233           2720        8062                0
# 2487200875 -122.393           1360        5000                0
# 1954400510 -122.045           1800        7503                0
# ...             ...            ...         ...              ...
# 263000018  -122.346           1530        1509                0
# 6600060120 -122.362           1830        7200                0
# 1523300141 -122.299           1020        2007                0
# 291310100  -122.069           1410        1287                1
# 1523300157 -122.299           1020        1357                0
#
#             waterfront_ind  yr_renovated_scheme1  yr_renovated_null  \
# id
# 7129300520               0                     0                  0
# 6414100192               0                     2                  0
# 5631500400               0                     1                  1
# 2487200875               0                     0                  0
# 1954400510               0                     0                  0
# ...                    ...                   ...                ...
# 263000018                0                     0                  0
# 6600060120               0                     0                  0
# 1523300141               0                     0                  0
# 291310100                0                     0                  0
# 1523300157               0                     0                  0
#
#             yr_renovated_ind
# id
# 7129300520                 0
# 6414100192                 1
# 5631500400                 0
# 2487200875                 0
# 1954400510                 0
# ...                      ...
# 263000018                  0
# 6600060120                 0
# 1523300141                 0
# 291310100                  0
# 1523300157                 0
#
# [21297 rows x 25 columns]

# %%
df = df[df['long'] < -121.85]
df.shape
# Out:
# (21297, 25)

# %%
df.isnull().sum()
# Out:
# date                       0
# price                      0
# bedrooms                   0
# bathrooms                  0
# sqft_living                0
# sqft_lot                   0
# floors                     0
# waterfront                 0
# view                      62
# condition                  0
# grade                      0
# sqft_above                 0
# sqft_basement              0
# yr_built                   0
# yr_renovated            3800
# zipcode                    0
# lat                        0
# long                       0
# sqft_living15              0
# sqft_lot15                 0
# waterfront_null            0
# waterfront_ind             0
# yr_renovated_scheme1       0
# yr_renovated_null          0
# yr_renovated_ind           0
# dtype: int64

# %%
# dropping the yr_renovated column and checking for other missing values.
del df['yr_renovated']
df.isnull().sum()
# Out:
# date                     0
# price                    0
# bedrooms                 0
# bathrooms                0
# sqft_living              0
# sqft_lot                 0
# floors                   0
# waterfront               0
# view                    62
# condition                0
# grade                    0
# sqft_above               0
# sqft_basement            0
# yr_built                 0
# zipcode                  0
# lat                      0
# long                     0
# sqft_living15            0
# sqft_lot15               0
# waterfront_null          0
# waterfront_ind           0
# yr_renovated_scheme1     0
# yr_renovated_null        0
# yr_renovated_ind         0
# dtype: int64

# %%
# This shows that the view column is a categorical column
df['view'].value_counts()
# Out:
# 0.0    19150
# 2.0      938
# 3.0      501
# 1.0      330
# 4.0      316
# Name: view, dtype: int64

# %%
df[df.view.isna() == True]
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 2008000270   1/15/2015   291850.0         3       1.50         1060      9711
# 8961960160  10/28/2014   480000.0         4       2.50         3230     16171
# 3456000310    8/4/2014   840000.0         4       1.75         2480     11010
# 1895000260   7/21/2014   207950.0         2       2.00          890      5000
# 2525069041    9/4/2014   505000.0         3       1.50         1830    217800
# ...                ...        ...       ...        ...          ...       ...
# 148000475    5/28/2014  1400000.0         4       3.25         4700      9160
# 291310170     8/4/2014   384500.0         3       2.50         1600      2610
# 1196003740   9/24/2014   734000.0         5       4.25         4110     42755
# 3448900290   8/28/2014   636230.0         4       2.50         2840      6284
# 3448900210  10/14/2014   610685.0         4       2.50         2520      6023
#
#             floors  waterfront  view  condition  ...  zipcode      lat  \
# id                                               ...
# 2008000270     1.0         0.0   NaN          3  ...    98198  47.4095
# 8961960160     2.0         0.0   NaN          3  ...    98001  47.3183
# 3456000310     1.0         0.0   NaN          4  ...    98040  47.5378
# 1895000260     1.0         0.0   NaN          3  ...    98118  47.5158
# 2525069041     1.0         0.0   NaN          3  ...    98053  47.6277
# ...            ...         ...   ...        ...  ...      ...      ...
# 148000475      1.0         0.0   NaN          3  ...    98116  47.5744
# 291310170      2.0         0.0   NaN          3  ...    98027  47.5344
# 1196003740     2.0         0.0   NaN          3  ...    98023  47.3375
# 3448900290     2.0         0.0   NaN          3  ...    98056  47.5135
# 3448900210     2.0         0.0   NaN          3  ...    98056  47.5137
#
#                long  sqft_living15  sqft_lot15  waterfront_null  \
# id
# 2008000270 -122.315           1650        9711                0
# 8961960160 -122.253           2640        8517                0
# 3456000310 -122.219           2770       10744                0
# 1895000260 -122.264           1860        5000                0
# 2525069041 -121.972           2450      165963                0
# ...             ...            ...         ...              ...
# 148000475  -122.406           2240        8700                0
# 291310170  -122.068           1445        1288                0
# 1196003740 -122.337           2730       12750                0
# 3448900290 -122.169           2790        7168                0
# 3448900210 -122.167           2520        6023                0
#
#             waterfront_ind  yr_renovated_scheme1  yr_renovated_null  \
# id
# 2008000270               0                     0                  0
# 8961960160               0                     0                  0
# 3456000310               0                     1                  1
# 1895000260               0                     0                  0
# 2525069041               0                     0                  0
# ...                    ...                   ...                ...
# 148000475                0                     0                  0
# 291310170                0                     1                  1
# 1196003740               0                     1                  1
# 3448900290               0                     0                  0
# 3448900210               0                     0                  0
#
#             yr_renovated_ind
# id
# 2008000270                 0
# 8961960160                 0
# 3456000310                 0
# 1895000260                 0
# 2525069041                 0
# ...                      ...
# 148000475                  0
# 291310170                  0
# 1196003740                 0
# 3448900290                 0
# 3448900210                 0
#
# [62 rows x 24 columns]

# %%
df[df.view.isna() == False]
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 7129300520  10/13/2014  221900.0         3       1.00         1180      5650
# 6414100192   12/9/2014  538000.0         3       2.25         2570      7242
# 5631500400   2/25/2015  180000.0         2       1.00          770     10000
# 2487200875   12/9/2014  604000.0         4       3.00         1960      5000
# 1954400510   2/18/2015  510000.0         3       2.00         1680      8080
# ...                ...       ...       ...        ...          ...       ...
# 263000018    5/21/2014  360000.0         3       2.50         1530      1131
# 6600060120   2/23/2015  400000.0         4       2.50         2310      5813
# 1523300141   6/23/2014  402101.0         2       0.75         1020      1350
# 291310100    1/16/2015  400000.0         3       2.50         1600      2388
# 1523300157  10/15/2014  325000.0         2       0.75         1020      1076
#
#             floors  waterfront  view  condition  ...  zipcode      lat  \
# id                                               ...
# 7129300520     1.0         1.0   0.0          3  ...    98178  47.5112
# 6414100192     2.0         0.0   0.0          3  ...    98125  47.7210
# 5631500400     1.0         0.0   0.0          3  ...    98028  47.7379
# 2487200875     1.0         0.0   0.0          5  ...    98136  47.5208
# 1954400510     1.0         0.0   0.0          3  ...    98074  47.6168
# ...            ...         ...   ...        ...  ...      ...      ...
# 263000018      3.0         0.0   0.0          3  ...    98103  47.6993
# 6600060120     2.0         0.0   0.0          3  ...    98146  47.5107
# 1523300141     2.0         0.0   0.0          3  ...    98144  47.5944
# 291310100      2.0         1.0   0.0          3  ...    98027  47.5345
# 1523300157     2.0         0.0   0.0          3  ...    98144  47.5941
#
#                long  sqft_living15  sqft_lot15  waterfront_null  \
# id
# 7129300520 -122.257           1340        5650                1
# 6414100192 -122.319           1690        7639                0
# 5631500400 -122.233           2720        8062                0
# 2487200875 -122.393           1360        5000                0
# 1954400510 -122.045           1800        7503                0
# ...             ...            ...         ...              ...
# 263000018  -122.346           1530        1509                0
# 6600060120 -122.362           1830        7200                0
# 1523300141 -122.299           1020        2007                0
# 291310100  -122.069           1410        1287                1
# 1523300157 -122.299           1020        1357                0
#
#             waterfront_ind  yr_renovated_scheme1  yr_renovated_null  \
# id
# 7129300520               0                     0                  0
# 6414100192               0                     2                  0
# 5631500400               0                     1                  1
# 2487200875               0                     0                  0
# 1954400510               0                     0                  0
# ...                    ...                   ...                ...
# 263000018                0                     0                  0
# 6600060120               0                     0                  0
# 1523300141               0                     0                  0
# 291310100                0                     0                  0
# 1523300157               0                     0                  0
#
#             yr_renovated_ind
# id
# 7129300520                 0
# 6414100192                 1
# 5631500400                 0
# 2487200875                 0
# 1954400510                 0
# ...                      ...
# 263000018                  0
# 6600060120                 0
# 1523300141                 0
# 291310100                  0
# 1523300157                 0
#
# [21235 rows x 24 columns]

# %%
#Since there were only 62 missing values for the view, we decided to drop them.
df = df[df.view.isna() == False]

# %%
# checking to see how many houses have 33 bedrooms. We decided to drop.
df[df.bedrooms == 33]
# Out:
#                  date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 2402100895  6/25/2014  640000.0        33       1.75         1620      6000
#
#             floors  waterfront  view  condition  ...  zipcode      lat  \
# id                                               ...
# 2402100895     1.0         0.0   0.0          5  ...    98103  47.6878
#
#                long  sqft_living15  sqft_lot15  waterfront_null  \
# id
# 2402100895 -122.331           1330        4700                0
#
#             waterfront_ind  yr_renovated_scheme1  yr_renovated_null  \
# id
# 2402100895               0                     0                  0
#
#             yr_renovated_ind
# id
# 2402100895                 0
#
# [1 rows x 24 columns]

# %%
df = df[df.bedrooms != 33]

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15', 'waterfront_null', 'waterfront_ind',
#        'yr_renovated_scheme1', 'yr_renovated_null', 'yr_renovated_ind'],
#       dtype='object')

# %%
# Inspecting how many datapoints have '?' on the sdft_basement
df[df.sqft_basement == '?']
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id
# 1321400060   6/27/2014   257500.0         3       2.25         1715      6819
# 16000397     12/5/2014   189000.0         2       1.00         1200      9850
# 7203220400    7/7/2014   861990.0         5       2.75         3595      5639
# 1531000030   3/23/2015   720000.0         4       2.50         3450     39683
# 2525310310   9/16/2014   272500.0         3       1.75         1540     12600
# ...                ...        ...       ...        ...          ...       ...
# 3226049565   7/11/2014   504600.0         5       3.00         2360      5000
# 1760650900   7/21/2014   337500.0         4       2.50         2330      4907
# 6021503707   1/20/2015   352500.0         2       2.50          980      1010
# 2909310100  10/15/2014   332000.0         4       2.50         2380      5737
# 191100405    4/21/2015  1580000.0         4       3.25         3410     10125
#
#             floors  waterfront  view  condition  ...  zipcode      lat  \
# id                                               ...
# 1321400060     2.0         0.0   0.0          3  ...    98003  47.3097
# 16000397       1.0         0.0   0.0          4  ...    98002  47.3089
# 7203220400     2.0         0.0   0.0          3  ...    98053  47.6848
# 1531000030     2.0         0.0   0.0          3  ...    98010  47.3420
# 2525310310     1.0         0.0   0.0          4  ...    98038  47.3624
# ...            ...         ...   ...        ...  ...      ...      ...
# 3226049565     1.0         0.0   0.0          3  ...    98103  47.6931
# 1760650900     2.0         0.0   0.0          3  ...    98042  47.3590
# 6021503707     3.0         1.0   0.0          3  ...    98117  47.6844
# 2909310100     2.0         0.0   0.0          3  ...    98023  47.2815
# 191100405      2.0         0.0   0.0          3  ...    98040  47.5653
#
#                long  sqft_living15  sqft_lot15  waterfront_null  \
# id
# 1321400060 -122.327           2238        6819                0
# 16000397   -122.210           1060        5095                0
# 7203220400 -122.016           3625        5639                0
# 1531000030 -122.025           3350       39750                0
# 2525310310 -122.031           1540       11656                0
# ...             ...            ...         ...              ...
# 3226049565 -122.330           2180        5009                0
# 1760650900 -122.081           2300        3836                0
# 6021503707 -122.387            980        1023                1
# 2909310100 -122.356           2380        5396                0
# 191100405  -122.223           2290       10125                0
#
#             waterfront_ind  yr_renovated_scheme1  yr_renovated_null  \
# id
# 1321400060               0                     0                  0
# 16000397                 0                     0                  0
# 7203220400               0                     0                  0
# 1531000030               0                     0                  0
# 2525310310               0                     0                  0
# ...                    ...                   ...                ...
# 3226049565               0                     0                  0
# 1760650900               0                     1                  1
# 6021503707               0                     0                  0
# 2909310100               0                     0                  0
# 191100405                0                     1                  1
#
#             yr_renovated_ind
# id
# 1321400060                 0
# 16000397                   0
# 7203220400                 0
# 1531000030                 0
# 2525310310                 0
# ...                      ...
# 3226049565                 0
# 1760650900                 0
# 6021503707                 0
# 2909310100                 0
# 191100405                  0
#
# [445 rows x 24 columns]

# %%
# Changing '?' in the basement with the difference between sqft_living and sqft_above
idx = df['sqft_basement'] == '?'
df['sqft_basement'].loc[idx] = df['sqft_living'].loc[idx] - df['sqft_above'].loc[idx]

# %%
df[df['sqft_basement'] == '?']
# Out:
# Empty DataFrame
# Columns: [date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, zipcode, lat, long, sqft_living15, sqft_lot15, waterfront_null, waterfront_ind, yr_renovated_scheme1, yr_renovated_null, yr_renovated_ind]
# Index: []
#
# [0 rows x 24 columns]

# %%
np.sum(df['sqft_basement'].loc[idx] < 0)
# Out:
# 0

# %%
df.sqft_basement.astype(float).astype(int)
# Out:
# id
# 7129300520      0
# 6414100192    400
# 5631500400      0
# 2487200875    910
# 1954400510      0
#              ...
# 263000018       0
# 6600060120      0
# 1523300141      0
# 291310100       0
# 1523300157      0
# Name: sqft_basement, Length: 21234, dtype: int64

# %%
df.sqft_basement = df.sqft_basement.astype(float).astype(int)

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'zipcode', 'lat', 'long', 'sqft_living15',
#        'sqft_lot15', 'waterfront_null', 'waterfront_ind',
#        'yr_renovated_scheme1', 'yr_renovated_null', 'yr_renovated_ind'],
#       dtype='object')

# %%
#Thisfunction helps check for outliers in the features of interest.
boxplot_cols = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
       'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_built', 'zipcode', 'lat', 'long', 'sqft_living15',
       'sqft_lot15', 'waterfront_null', 'waterfront_ind',
       'yr_renovated_scheme1', 'yr_renovated_null', 'yr_renovated_ind']

# left out sqft_basement
def print_boxplot(df):
   for c in df[boxplot_cols]:
       sns.boxplot(df[c])
       plt.show()
    
print_boxplot(df)

# %%
ls
# Out:
# ColumnNames.md              clean_data.ipynb
# Mod2-Project_HTX-DS-111819/ kc_house_data.csv
# README.md                   kc_housing.ipynb
# Untitled.ipynb              king_county_edna.ipynb

# %%
df.to_csv('kc_house_data_clean.csv')

# %%
ls
# Out:
# ColumnNames.md              kc_house_data.csv
# Mod2-Project_HTX-DS-111819/ kc_house_data_clean.csv
# README.md                   kc_housing.ipynb
# Untitled.ipynb              king_county_edna.ipynb
# clean_data.ipynb

# %%
df.shape
# Out:
# (21234, 24)
